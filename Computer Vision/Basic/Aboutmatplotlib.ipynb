# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y_0 = np.array([1,3,9,6,2,1])
y_1 = np.array([10,5,9,3,1,15])
plt.plot(x,y_0,'g',lw = 3)
#1.x坐标 2.y坐标 3.颜色 4.折线宽
plt.bar(x,y_1,0.5,alpha = 0.1,color = 'b')
#1.x坐标 2.y坐标 3.柱宽百分比0-1 4.透明度 5.颜色
# Out:
# <BarContainer object of 6 artists>
